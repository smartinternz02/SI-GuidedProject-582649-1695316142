# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# ###Task-1,2

# %%
#Task-1,2
#downloaded dataset

#loading dataset
df=pd.read_csv("/content/House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'Date',
#  'number of bedrooms',
#  'number of bathrooms',
#  'living area',
#  'lot area',
#  'number of floors',
#  'waterfront present',
#  'number of views',
#  'condition of the house',
#  'grade of the house',
#  'Area of the house(excluding basement)',
#  'Area of the basement',
#  'Built Year',
#  'Renovation Year',
#  'Postal Code',
#  'Lattitude',
#  'Longitude',
#  'living_area_renov',
#  'lot_area_renov',
#  'Number of schools nearby',
#  'Distance from the airport',
#  'Price']

# %%
df.shape
# Out:
# (14620, 23)

# %% [markdown]
# ###Task-3

# %% [markdown]
# #Visualizations

# %% [markdown]
# ##Univariate Analysis

# %%
sns.distplot(df["living area"])
# Out:
# <ipython-input-6-cb9a9da508b2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["living area"])
# <Axes: xlabel='living area', ylabel='Density'>

# %%
sns.displot(df["grade of the house"])

# %%
df["condition of the house"].unique()
# Out:
# array([5, 3, 4, 2, 1])

# %%
df["condition of the house"].value_counts()
# Out:
# 3    9350
# 4    3874
# 5    1278
# 2     100
# 1      18
# Name: condition of the house, dtype: int64

# %%
plt.pie(df["condition of the house"].value_counts(),[0.3,0.2,0.2,0,0.2],labels=['3','4','5','2','1'],autopct ='%1.1f%%',colors = ['purple','yellow','blue','green','orange'],)
plt.title('House Condition')
plt.show()

# %%
df["number of bedrooms"].value_counts()
# Out:
# 3     6612
# 4     4724
# 2     1844
# 5     1079
# 6      176
# 1      136
# 7       30
# 8       11
# 9        3
# 10       3
# 33       1
# 11       1
# Name: number of bedrooms, dtype: int64

# %%
sns.barplot(x =df["number of bedrooms"].value_counts().index,y =df["number of bedrooms"].value_counts() )
# Out:
# <Axes: ylabel='number of bedrooms'>

# %% [markdown]
# ##Bivariate Analysis

# %%
sns.lineplot(x = df["number of bedrooms"],y=df["Price"])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x=df["Area of the basement"],y=df["number of bedrooms"])
# Out:
# <Axes: xlabel='Area of the basement', ylabel='number of bedrooms'>

# %% [markdown]
# ##Multivariate Analysis

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###Task-4

# %%
#descriptive statistics
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# ###Task-5

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %% [markdown]
# since the dataset has no null values, there is no meaning of handling missing values in the dataset.
