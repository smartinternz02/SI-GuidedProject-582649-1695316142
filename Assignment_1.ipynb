# %%
import pandas as pd
import numpy as np

# %%
data =[["realme","64GB","6GB","32MP","HIGH"],
       ["oppo","64GB","128GB","48MP","moderate"],
       ["samsung","64GB","8GB","64MP","low"],
       ["poco","64GB","6GB","32MP","HIGH"],
       ["oneplus","256GB","6GB","108MP","HIGH"],
       ["oppof19","128GB","8GB","72MP","HIGH"],
       ["realme nord","256GB","8GB","48MP","HIGH"],
       ["vivo v17","128GB","6GB","64MP","low"],
       ["sony","256GB","8GB","100MP","HIGH"],
       ["asus","128GB","12GB","78MP","low"]]

# %%
#Task-1
df=pd.DataFrame(data,columns=['mobile','storage','ram','camera','battery'])
df
# Out:
#         mobile storage    ram camera   battery
# 0       realme    64GB    6GB   32MP      HIGH
# 1         oppo    64GB  128GB   48MP  moderate
# 2      samsung    64GB    8GB   64MP       low
# 3         poco    64GB    6GB   32MP      HIGH
# 4      oneplus   256GB    6GB  108MP      HIGH
# 5      oppof19   128GB    8GB   72MP      HIGH
# 6  realme nord   256GB    8GB   48MP      HIGH
# 7     vivo v17   128GB    6GB   64MP       low
# 8         sony   256GB    8GB  100MP      HIGH
# 9         asus   128GB   12GB   78MP       low

# %%
#task-2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mobile   10 non-null     object
#  1   storage  10 non-null     object
#  2   ram      10 non-null     object
#  3   camera   10 non-null     object
#  4   battery  10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes

# %%
#task-3
df.describe()
# Out:
#         mobile storage  ram camera battery
# count       10      10   10     10      10
# unique      10       3    4      7       3
# top     realme    64GB  6GB   32MP    HIGH
# freq         1       4    4      2       6

# %%
#task-4
df.iloc[4:5,:]
# Out:
#     mobile storage  ram camera battery
# 4  oneplus   256GB  6GB  108MP    HIGH

# %%
#task-5
df.isnull()
# Out:
#    mobile  storage    ram  camera  battery
# 0   False    False  False   False    False
# 1   False    False  False   False    False
# 2   False    False  False   False    False
# 3   False    False  False   False    False
# 4   False    False  False   False    False
# 5   False    False  False   False    False
# 6   False    False  False   False    False
# 7   False    False  False   False    False
# 8   False    False  False   False    False
# 9   False    False  False   False    False
